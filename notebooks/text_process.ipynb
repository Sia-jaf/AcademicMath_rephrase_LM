# %% [markdown]
# ***Define class for processing the math text***
#
# As it is different for each single tex file, making it as a class makes more sense.

# %%
class MathExpr:
    pass
    '''
    def __init__(self=str, content=str, size=int):
        self.size = size
        self.content=content
    '''

a = "this is just a text with $\\alpha$.\n and a new line"
