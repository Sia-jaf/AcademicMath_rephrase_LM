# %%
# This notebook serves as a practice to tokenizing a text file.

import os
import re

# Path to the txt file.
file_path = ""

# %%
with open("../data/paper_1.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

# %% [markdown]
# **RegEx Functions**
#
# The re module offers a set of functions that allows us to search a string for a match:
#
# |Function | Description|
# |:--------|:-----------|
# |findall |Returns a list containing all matches|
# |search |Returns a Match object if there is a match anywhere in the string|
# |split |Returns a list where the string has been split at each match|
# |sub |Replaces one or many matches with a string|

# %%
split_txt = re.split(r'(\s)',raw_text)

print(len(split_txt))
print()
print(split_txt[2000:2000+25])
# Out:
# 58397
#
# ['$\\Crossings$', ' ', 'one', ' ', 'can', ' ', 'consider', ' ', 'the', '\n', 'cube', ' ', 'of', ' ', 'resolutions', ' ', 'of', ' ', '$L$,', ' ', 'a', ' ', 'functor', ' ', 'from']
